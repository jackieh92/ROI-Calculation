# %%
class Should_i():
    def __init__ (self, monthly_expenses, monthly_income):
        self.monthly_expenses = monthly_expenses
        self.monthly_income = monthly_income
    
    
    def monthlyincome(self):
        self.monthly_income = float(input("\n * What is your total monthly income? \n"))
        return self.monthly_income
    
    
    def monthlyexpenses(self):
        self.monthly_expenses = float(input("\n * What is your total monthly expenditure? \n"))
        return self.monthly_expenses
    
    
    def cashflow(self):
        self.cashflow = (self.monthly_income * 12) - (self.monthly_expenses * 12)
        print(f" \n * Your annual cashflow is {self.cashflow}. \n")
        return self.cashflow
    
    
    def roi(self):
        total_investment = float(input("\n * Please enter total investment. \n"))
        self.roi = self.cashflow / total_investment * 100 
        print(f"\n* This property's ROI is expected to be: {round(self.roi,2)}%.\n *This property's cashflow is expected to be {self.cashflow}\n")  
        if self.roi <= 0:
            print("This is not a good investment.\n")
        else:
            print("*\n To gauge whether this is a good investment click this link here: https://www.youtube.com/watch?time_continue=1182&v=T_7vhsSBi7c&feature=emb_title\n")
        
    def payback(self):
        initial_investment = float(input("\n * Please enter your initital investment. \n"))
        how_long = int(input("\n Please enter the amount of years you would like to pay the initial investment off. \n"))
        self.cashflow = float(input("\n * Please enter your monthly cashflow. \n"))
        cummulative_cashflow = (self.cashflow * 12) * how_long
        if initial_investment > cummulative_cashflow:
            print (f"\n * You will be unable to pay this investment off in {how_long} years. \n")
        else:
            print(f"\n * Congrats, you will be able to pay this investment off in {how_long} years. \n")
            

def calculate():
    property1 = Should_i(input,input)
    while True:
        firstinput = input("\n* What would you like to do: Calculate ROI: enter ROI | Investment Payback: enter payback | To Exit: enter exit\n")
        if firstinput.lower() == "roi":
            property1.monthlyincome()
            property1.monthlyexpenses()
            property1.cashflow()
            property1.roi()
        if firstinput.lower() == "payback":
            property1.payback()
        if firstinput.lower() == "exit":
            break
calculate()
# Out:
# * What would you like to do: Calculate ROI: enter ROI | Investment Payback: enter payback | To Exit: enter exit
# roi
#
#  * What is your total monthly income?
# 5000
#
#  * What is your total monthly expenditure?
# 500
#
#  * Your annual cashflow is 54000.0.
#
#
#  * Please enter total investment.
# 180000
#
# * This property's ROI is expected to be: 30.0%.
#  *This property's cashflow is expected to be 54000.0
#
# *
#  To gauge whether this is a good investment click this link here: https://www.youtube.com/watch?time_continue=1182&v=T_7vhsSBi7c&feature=emb_title
